# %%
import numpy as np 
import pandas as pd 

df = pd.DataFrame(pd.read_csv("Seattle_Police_Department_Police_Report_Incident.csv"))
df.fillna(0, inplace=True)
df1= df[~((df[['General Offense Number']].duplicated(keep=False))) & (df.isnull().any(axis=1))]
## Has no duplicate entries for General Offense Number now 
df1 = df[(df['Year'] > 2012)]

# %%
df1.head()
# Out:
#    RMS CDW ID  General Offense Number Offense Code  Offense Code Extension  \
# 0      887754               201378203         2299                       2
# 3     1032238               201472111         2404                       8
# 4     1032239              2014107311         2202                       0
# 5      887755               201377887         2299                       2
# 6     1032241              2014123990         2404                       1
#
#                   Offense Type Summary Offense Code  \
# 0  BURGLARY-SECURE PARKING-RES                 2299
# 3              VEH-THEFT-TRUCK                 2400
# 4           BURGLARY-FORCE-RES                 2200
# 5  BURGLARY-SECURE PARKING-RES                 2299
# 6               VEH-THEFT-AUTO                 2400
#
#   Summarized Offense Description           Date Reported  \
# 0    BURGLARY-SECURE PARKING-RES  03/07/2013 04:29:00 PM
# 3                  VEHICLE THEFT  03/08/2014 06:57:00 AM
# 4                       BURGLARY  04/08/2014 03:59:00 PM
# 5    BURGLARY-SECURE PARKING-RES  03/07/2013 11:59:00 AM
# 6                  VEHICLE THEFT  04/23/2014 08:29:00 AM
#
#   Occurred Date or Date Range Start Occurred Date Range End  \
# 0            03/07/2013 04:29:00 PM                       0
# 3            03/07/2014 10:00:00 PM  03/08/2014 06:30:00 AM
# 4            04/08/2014 10:30:00 AM  04/08/2014 03:59:00 PM
# 5            03/05/2013 03:30:00 PM  03/06/2013 07:15:00 AM
# 6            04/22/2014 06:15:00 PM  04/23/2014 08:25:00 AM
#
#        Hundred Block Location District/Sector Zone/Beat  Census Tract 2000  \
# 0  60XX BLOCK OF PHINNEY AV N               B        B2          3500.2037
# 3            CHERRY ST / 2 AV               K        K1          8100.2036
# 4     130XX BLOCK OF 25 AV NE               L        L1           200.2001
# 5         1XX BLOCK OF 6 AV N               Q        Q3          7200.1075
# 6      22XX BLOCK OF NW 64 ST               B        B1          3300.4006
#
#     Longitude   Latitude                        Location  Month  Year
# 0 -122.354378  47.672829  (47.672828674, -122.354377747)      3  2013
# 3 -122.333176  47.603016    (47.6030159, -122.333175659)      3  2014
# 4 -122.301888  47.723846  (47.723846436, -122.301887512)      4  2014
# 5 -122.345009  47.619144    (47.61914444, -122.34500885)      3  2013
# 6 -122.386162  47.675289  (47.675289154, -122.386161804)      4  2014

# %% [markdown]
# # Data Exploration

# %% [markdown]
# The link at the bottom of this notebook provides a detailed map of how the districts and zone/beats are defined within the Seattle City Limits. Lets take a look at how much crime occurs in downtown Seattle:

# %%
m = []
for line in df1['District/Sector']:
    if line == 'M':
        m.append(line)

# %%
print(len(m)/len(df1['District/Sector']))
len(m)
# Out:
# 0.08296507684218554
# 41341

# %% [markdown]
# Approximately 8% of all the reported crime events in Seattle take place in downtown. A bit high, but not too suprising if you've ever driven past Pike and Pine after 10PM.

# %%
df1.groupby('District/Sector').count()['RMS CDW ID']
# Out:
# District/Sector
# 0       613
# 99      785
# B     34797
# C     21714
# D     32868
# E     39640
# F     24905
# G     22594
# J     26683
# K     30971
# L     28682
# M     41341
# N     32545
# O     15827
# Q     31553
# R     27211
# S     22018
# SE        2
# U     38854
# W     24691
# Name: RMS CDW ID, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.plot(df1['District/Sector'].value_counts(), 'ro')
plt.show()

# %%
plt.plot(df1['Summarized Offense Description'].value_counts()[:5], 'ro')
plt.show()

# %%
df1 = df1.drop(['RMS CDW ID','Offense Type','Offense Code','Date Reported','Location','General Offense Number','Occurred Date Range End','Hundred Block Location','Offense Code Extension','Summary Offense Code','Latitude','Longitude'],axis=1)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 498294 entries, 0 to 766471
# Data columns (total 7 columns):
# Summarized Offense Description       498294 non-null object
# Occurred Date or Date Range Start    498294 non-null object
# District/Sector                      498294 non-null object
# Zone/Beat                            498294 non-null object
# Census Tract 2000                    498294 non-null float64
# Month                                498294 non-null int64
# Year                                 498294 non-null int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 30.4+ MB

# %% [markdown]
# A half a million data points is a lot to work with. In order to make this dataset more malleable, we will do some very light feature engineering to change the resolution of the types of crime; we will no longer look at individual types of offenses but instead classify them in terms of severity:

# %%
df2 = df1.copy()
df2['Severity'] = 'LOW'
sev_high = ['ASSAULT', 'HOMICIDE', 'NARCOTICS', 'ROBBERY', 'THREATS', 'VEHICLE THEFT', 'WEAPON','BURGLARY']
sev_med  = ['BIKE THEFT','BURGLARY-SECURE PARKING-RES','CAR PROWL','COUNTERFEIT','DUI','EMBEZZLE','FORGERY','FRAUD','INJURY','LOST PROPERTY','OBSTRUCT','OTHER PROPERTY','PICKPOCKET','PROPERTY DAMAGE','PROSTITUTION','STOLEN PROPERTY','TRAFFIC','WARRANT ARREST']


df2.loc[df['Summarized Offense Description'].isin(sev_high), 'Severity'] = 'HIGH'
df2.loc[df['Summarized Offense Description'].isin(sev_med), 'Severity'] = 'MED'

# Filter and display

df_sev = df2.groupby(['Severity']).size().reset_index(name='incidents')
df_sev.head()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 498294 entries, 0 to 766471
# Data columns (total 8 columns):
# Summarized Offense Description       498294 non-null object
# Occurred Date or Date Range Start    498294 non-null object
# District/Sector                      498294 non-null object
# Zone/Beat                            498294 non-null object
# Census Tract 2000                    498294 non-null float64
# Month                                498294 non-null int64
# Year                                 498294 non-null int64
# Severity                             498294 non-null object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 34.2+ MB

# %%
df2['Hour'] = (pd.to_datetime(df2['Occurred Date or Date Range Start'])).dt.hour

# %% [markdown]
# An interesting measurand for our model would be whether or not a crime occurred at night. Of course, "night" is very subjective, but it is definitely not encoded by just AM or PM. The following cell encodes whether a crime occurred at night or not based on the definition that "night" is between the hours of 7PM and 6AM. This will then be imbibed into our dataframe and be used as a feature in place of the Date & Time column.

# %%
day_night = []
for i in df2['Hour']:

    if i > 19 or i < 6 :
        day_night.append('Night')
    elif 6 <= i <= 19:
        day_night.append('Day')
day_night
# Out:
# ['Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Night',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Night',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Night',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Night',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Night',
#  'Night',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Day',
#  'Night',
#  'Night',
#  'Day',
#  ...]

# %%
from sklearn.preprocessing import LabelBinarizer
one_hot = LabelBinarizer()
one_hot.fit_transform(day_night)
# Out:
# array([[0],
#        [1],
#        [0],
#        ...,
#        [0],
#        [0],
#        [1]])

# %%
one_hot.classes_
# Out:
# array(['Day', 'Night'],
#       dtype='<U5')

# %%
daynight = pd.Series(day_night)
daynight_cols = pd.get_dummies(daynight)
daynight_df = pd.DataFrame(daynight_cols)
daynight_df.head()
# Out:
#    Day  Night
# 0    1      0
# 1    0      1
# 2    1      0
# 3    1      0
# 4    1      0

# %%
df2 = df2.reset_index(drop=True)
frames = [df2,daynight_df]
df2.head()
# Out:
#   Summarized Offense Description Occurred Date or Date Range Start  \
# 0    BURGLARY-SECURE PARKING-RES            03/07/2013 04:29:00 PM
# 1                  VEHICLE THEFT            03/07/2014 10:00:00 PM
# 2                       BURGLARY            04/08/2014 10:30:00 AM
# 3    BURGLARY-SECURE PARKING-RES            03/05/2013 03:30:00 PM
# 4                  VEHICLE THEFT            04/22/2014 06:15:00 PM
#
#   District/Sector Zone/Beat  Census Tract 2000  Month  Year Severity  Hour
# 0               B        B2          3500.2037      3  2013      MED    16
# 1               K        K1          8100.2036      3  2014     HIGH    22
# 2               L        L1           200.2001      4  2014     HIGH    10
# 3               Q        Q3          7200.1075      3  2013      MED    15
# 4               B        B1          3300.4006      4  2014     HIGH    18

# %%
df3 = pd.concat(frames,axis=1,join_axes=[df2.index])
df3.head()
# Out:
#   Summarized Offense Description Occurred Date or Date Range Start  \
# 0    BURGLARY-SECURE PARKING-RES            03/07/2013 04:29:00 PM
# 1                  VEHICLE THEFT            03/07/2014 10:00:00 PM
# 2                       BURGLARY            04/08/2014 10:30:00 AM
# 3    BURGLARY-SECURE PARKING-RES            03/05/2013 03:30:00 PM
# 4                  VEHICLE THEFT            04/22/2014 06:15:00 PM
#
#   District/Sector Zone/Beat  Census Tract 2000  Month  Year Severity  Hour  \
# 0               B        B2          3500.2037      3  2013      MED    16
# 1               K        K1          8100.2036      3  2014     HIGH    22
# 2               L        L1           200.2001      4  2014     HIGH    10
# 3               Q        Q3          7200.1075      3  2013      MED    15
# 4               B        B1          3300.4006      4  2014     HIGH    18
#
#    Day  Night
# 0    1      0
# 1    0      1
# 2    1      0
# 3    1      0
# 4    1      0

# %%
import datetime 
weekday = []
for i in df3['Occurred Date or Date Range Start']:
    A = pd.to_datetime(i).weekday()
    weekday.append(A)

# %%
weekday_df = pd.DataFrame(pd.get_dummies(pd.Series(weekday)))
weekday_df.columns = ['M','T','W','Th','F','Sa','Su']

# %%
frames1 = [weekday_df, df3]
df3
# Out:
#        Summarized Offense Description Occurred Date or Date Range Start  \
# 0         BURGLARY-SECURE PARKING-RES            03/07/2013 04:29:00 PM
# 1                       VEHICLE THEFT            03/07/2014 10:00:00 PM
# 2                            BURGLARY            04/08/2014 10:30:00 AM
# 3         BURGLARY-SECURE PARKING-RES            03/05/2013 03:30:00 PM
# 4                       VEHICLE THEFT            04/22/2014 06:15:00 PM
# 5                       VEHICLE THEFT            04/24/2014 05:30:00 AM
# 6                             ROBBERY            04/19/2014 11:30:00 PM
# 7                       VEHICLE THEFT            04/21/2014 10:30:00 PM
# 8                            BURGLARY            03/08/2013 05:00:00 PM
# 9                            BURGLARY            03/04/2013 08:00:00 PM
# 10                           BURGLARY            03/06/2013 06:02:00 PM
# 11                           BURGLARY            03/03/2013 09:30:00 AM
# 12                           BURGLARY            03/07/2013 01:26:00 PM
# 13                    PROPERTY DAMAGE            03/07/2013 11:00:00 AM
# 14                     OTHER PROPERTY            08/21/2014 06:42:00 PM
# 15        BURGLARY-SECURE PARKING-RES            03/03/2013 10:00:00 PM
# 16                             WEAPON            03/07/2013 09:15:00 AM
# 17                            ASSAULT            03/08/2013 11:07:00 AM
# 18                     WARRANT ARREST            03/08/2013 11:28:00 PM
# 19                          CAR PROWL            07/19/2014 02:00:00 PM
# 20                            ROBBERY            03/08/2013 08:35:00 PM
# 21                      VEHICLE THEFT            03/06/2013 06:00:00 PM
# 22                            THREATS            03/07/2013 12:00:00 AM
# 23                     WARRANT ARREST            03/08/2013 08:39:00 PM
# 24                     WARRANT ARREST            03/07/2013 12:13:00 AM
# 25                    PROPERTY DAMAGE            03/07/2013 12:30:00 AM
# 26                          CAR PROWL            03/06/2013 08:30:00 PM
# 27                           BURGLARY            08/19/2014 07:20:00 AM
# 28                     OTHER PROPERTY            02/28/2013 10:00:00 PM
# 29                           BURGLARY            05/25/2015 01:30:00 AM
# ...                               ...                               ...
# 498264                          FRAUD            03/07/2013 07:00:00 PM
# 498265                          FRAUD            02/14/2013 10:00:00 AM
# 498266                          FRAUD            09/01/2012 12:00:00 AM
# 498267                          FRAUD            02/07/2013 08:00:00 AM
# 498268                          FRAUD            03/08/2013 01:58:00 PM
# 498269                       EMBEZZLE            03/08/2013 02:18:00 PM
# 498270                          FRAUD            03/08/2013 06:27:00 PM
# 498271                       BURGLARY            03/07/2013 07:30:00 AM
# 498272                       BURGLARY            03/06/2013 08:00:00 AM
# 498273                   PROSTITUTION            03/08/2013 12:13:00 AM
# 498274                   PROSTITUTION            03/08/2013 01:55:00 AM
# 498275                 WARRANT ARREST            03/08/2013 02:40:00 AM
# 498276                 WARRANT ARREST            03/08/2013 02:48:00 AM
# 498277                        THREATS            03/07/2013 11:26:00 PM
# 498278    BURGLARY-SECURE PARKING-RES            03/07/2013 10:10:00 AM
# 498279                        ASSAULT            03/08/2013 01:55:00 PM
# 498280                 OTHER PROPERTY            03/08/2013 12:00:00 AM
# 498281                        ROBBERY            03/08/2013 06:07:00 PM
# 498282                    SHOPLIFTING            03/08/2013 05:30:00 PM
# 498283                STOLEN PROPERTY            03/08/2013 02:56:00 PM
# 498284                     BIKE THEFT            03/07/2013 02:20:00 PM
# 498285                     BIKE THEFT            03/06/2013 07:30:00 PM
# 498286                     BIKE THEFT            03/07/2013 11:00:00 PM
# 498287                     BIKE THEFT            03/08/2013 08:03:00 AM
# 498288                    DISTURBANCE            03/08/2013 10:28:00 PM
# 498289                       BURGLARY            03/08/2013 11:00:00 AM
# 498290                        ASSAULT            03/07/2013 04:54:00 PM
# 498291                  VEHICLE THEFT            03/07/2013 07:00:00 PM
# 498292                        ASSAULT            03/08/2013 04:55:00 PM
# 498293    BURGLARY-SECURE PARKING-RES            02/15/2013 12:01:00 AM
#
#        District/Sector Zone/Beat  Census Tract 2000  Month  Year Severity  \
# 0                    B        B2          3500.2037      3  2013      MED
# 1                    K        K1          8100.2036      3  2014     HIGH
# 2                    L        L1           200.2001      4  2014     HIGH
# 3                    Q        Q3          7200.1075      3  2013      MED
# 4                    B        B1          3300.4006      4  2014     HIGH
# 5                    J        J2          3000.4011      4  2014     HIGH
# 6                    D        D3          7300.2005      4  2014     HIGH
# 7                    N        N3          1200.5011      4  2014     HIGH
# 8                    M        M2          7200.1065      3  2013     HIGH
# 9                    C        C3          6300.4020      3  2013     HIGH
# 10                   Q        Q2          6800.2008      3  2013     HIGH
# 11                   Q        Q3          7200.1075      3  2013     HIGH
# 12                   Q        Q3          7000.6010      3  2013     HIGH
# 13                   G        G3          8900.3022      3  2013      MED
# 14                   L        L2          1200.3000      8  2014      MED
# 15                   E        E1          7402.1010      3  2013      MED
# 16                   N        N3          1300.1011      3  2013     HIGH
# 17                   S        S3         11900.1011      3  2013     HIGH
# 18                   O        O3         10900.2082      3  2013      MED
# 19                   K        K1          8100.1023      8  2014      MED
# 20                   F        F2         11402.1011      3  2013     HIGH
# 21                   B        B1          4700.4014      3  2013     HIGH
# 22                   W        W1          9600.3009      3  2013     HIGH
# 23                   0         0             0.0000      3  2013      MED
# 24                   C        C1          7500.2008      3  2013      MED
# 25                   W        W1          9701.2004      3  2013      MED
# 26                   Q        Q2          7000.1002      3  2013      MED
# 27                   R        R1          9300.1025      8  2014     HIGH
# 28                   D        D3          7300.3009      3  2013      MED
# 29                   M        M1          8100.3014      5  2015     HIGH
# ...                ...       ...                ...    ...   ...      ...
# 498264               S        S2         11800.6003      3  2013      MED
# 498265               K        K1          8100.2023      3  2013      MED
# 498266               S        S3         11700.4005      3  2013      MED
# 498267               Q        Q2          5900.1022      3  2013      MED
# 498268               C        C3          8800.1012      3  2013      MED
# 498269               W        W1          9900.1021      3  2013      MED
# 498270               W        W1          9600.1006      3  2013      MED
# 498271               S        S3         11800.2000      3  2013     HIGH
# 498272               W        W2          9702.2000      3  2013     HIGH
# 498273               D        D1          8001.2009      3  2013      MED
# 498274               M        M3          8100.2007      3  2013      MED
# 498275               N        N1          1400.3010      3  2013      MED
# 498276               D        D1          8001.1005      3  2013      MED
# 498277               Q        Q3          7100.1001      3  2013     HIGH
# 498278               E        E1          8400.1003      3  2013      MED
# 498279               J        J3          2700.4010      3  2013     HIGH
# 498280               D        D3          6100.3010      3  2013      MED
# 498281               O        O1          9300.1046      3  2013     HIGH
# 498282               E        E1          7402.1000      3  2013      LOW
# 498283               E        E2          8600.2006      3  2013      MED
# 498284               J        J2          3000.1002      3  2013      MED
# 498285               B        B3          5400.3002      3  2013      MED
# 498286               D        D3          6600.1041      3  2013      MED
# 498287               D        D2          7200.3000      3  2013      MED
# 498288               D        D1          8001.2001      3  2013      LOW
# 498289               U        U1          4400.4000      3  2013     HIGH
# 498290               U        U2          5301.2001      3  2013     HIGH
# 498291               D        D2          6700.1015      3  2013     HIGH
# 498292               F        F1         10800.3011      3  2013     HIGH
# 498293               B        B2          4900.4004      3  2013      MED
#
#         Hour  Day  Night
# 0         16    1      0
# 1         22    0      1
# 2         10    1      0
# 3         15    1      0
# 4         18    1      0
# 5          5    0      1
# 6         23    0      1
# 7         22    0      1
# 8         17    1      0
# 9         20    0      1
# 10        18    1      0
# 11         9    1      0
# 12        13    1      0
# 13        11    1      0
# 14        18    1      0
# 15        22    0      1
# 16         9    1      0
# 17        11    1      0
# 18        23    0      1
# 19        14    1      0
# 20        20    0      1
# 21        18    1      0
# 22         0    0      1
# 23        20    0      1
# 24         0    0      1
# 25         0    0      1
# 26        20    0      1
# 27         7    1      0
# 28        22    0      1
# 29         1    0      1
# ...      ...  ...    ...
# 498264    19    1      0
# 498265    10    1      0
# 498266     0    0      1
# 498267     8    1      0
# 498268    13    1      0
# 498269    14    1      0
# 498270    18    1      0
# 498271     7    1      0
# 498272     8    1      0
# 498273     0    0      1
# 498274     1    0      1
# 498275     2    0      1
# 498276     2    0      1
# 498277    23    0      1
# 498278    10    1      0
# 498279    13    1      0
# 498280     0    0      1
# 498281    18    1      0
# 498282    17    1      0
# 498283    14    1      0
# 498284    14    1      0
# 498285    19    1      0
# 498286    23    0      1
# 498287     8    1      0
# 498288    22    0      1
# 498289    11    1      0
# 498290    16    1      0
# 498291    19    1      0
# 498292    16    1      0
# 498293     0    0      1
#
# [498294 rows x 11 columns]

# %%
df4 = pd.concat(frames1, axis=1,join_axes=[df3.index])
df4
# Out:
#         M  T  W  Th  F  Sa  Su Summarized Offense Description  \
# 0       0  0  0   1  0   0   0    BURGLARY-SECURE PARKING-RES
# 1       0  0  0   0  1   0   0                  VEHICLE THEFT
# 2       0  1  0   0  0   0   0                       BURGLARY
# 3       0  1  0   0  0   0   0    BURGLARY-SECURE PARKING-RES
# 4       0  1  0   0  0   0   0                  VEHICLE THEFT
# 5       0  0  0   1  0   0   0                  VEHICLE THEFT
# 6       0  0  0   0  0   1   0                        ROBBERY
# 7       1  0  0   0  0   0   0                  VEHICLE THEFT
# 8       0  0  0   0  1   0   0                       BURGLARY
# 9       1  0  0   0  0   0   0                       BURGLARY
# 10      0  0  1   0  0   0   0                       BURGLARY
# 11      0  0  0   0  0   0   1                       BURGLARY
# 12      0  0  0   1  0   0   0                       BURGLARY
# 13      0  0  0   1  0   0   0                PROPERTY DAMAGE
# 14      0  0  0   1  0   0   0                 OTHER PROPERTY
# 15      0  0  0   0  0   0   1    BURGLARY-SECURE PARKING-RES
# 16      0  0  0   1  0   0   0                         WEAPON
# 17      0  0  0   0  1   0   0                        ASSAULT
# 18      0  0  0   0  1   0   0                 WARRANT ARREST
# 19      0  0  0   0  0   1   0                      CAR PROWL
# 20      0  0  0   0  1   0   0                        ROBBERY
# 21      0  0  1   0  0   0   0                  VEHICLE THEFT
# 22      0  0  0   1  0   0   0                        THREATS
# 23      0  0  0   0  1   0   0                 WARRANT ARREST
# 24      0  0  0   1  0   0   0                 WARRANT ARREST
# 25      0  0  0   1  0   0   0                PROPERTY DAMAGE
# 26      0  0  1   0  0   0   0                      CAR PROWL
# 27      0  1  0   0  0   0   0                       BURGLARY
# 28      0  0  0   1  0   0   0                 OTHER PROPERTY
# 29      1  0  0   0  0   0   0                       BURGLARY
# ...    .. .. ..  .. ..  ..  ..                            ...
# 498264  0  0  0   1  0   0   0                          FRAUD
# 498265  0  0  0   1  0   0   0                          FRAUD
# 498266  0  0  0   0  0   1   0                          FRAUD
# 498267  0  0  0   1  0   0   0                          FRAUD
# 498268  0  0  0   0  1   0   0                          FRAUD
# 498269  0  0  0   0  1   0   0                       EMBEZZLE
# 498270  0  0  0   0  1   0   0                          FRAUD
# 498271  0  0  0   1  0   0   0                       BURGLARY
# 498272  0  0  1   0  0   0   0                       BURGLARY
# 498273  0  0  0   0  1   0   0                   PROSTITUTION
# 498274  0  0  0   0  1   0   0                   PROSTITUTION
# 498275  0  0  0   0  1   0   0                 WARRANT ARREST
# 498276  0  0  0   0  1   0   0                 WARRANT ARREST
# 498277  0  0  0   1  0   0   0                        THREATS
# 498278  0  0  0   1  0   0   0    BURGLARY-SECURE PARKING-RES
# 498279  0  0  0   0  1   0   0                        ASSAULT
# 498280  0  0  0   0  1   0   0                 OTHER PROPERTY
# 498281  0  0  0   0  1   0   0                        ROBBERY
# 498282  0  0  0   0  1   0   0                    SHOPLIFTING
# 498283  0  0  0   0  1   0   0                STOLEN PROPERTY
# 498284  0  0  0   1  0   0   0                     BIKE THEFT
# 498285  0  0  1   0  0   0   0                     BIKE THEFT
# 498286  0  0  0   1  0   0   0                     BIKE THEFT
# 498287  0  0  0   0  1   0   0                     BIKE THEFT
# 498288  0  0  0   0  1   0   0                    DISTURBANCE
# 498289  0  0  0   0  1   0   0                       BURGLARY
# 498290  0  0  0   1  0   0   0                        ASSAULT
# 498291  0  0  0   1  0   0   0                  VEHICLE THEFT
# 498292  0  0  0   0  1   0   0                        ASSAULT
# 498293  0  0  0   0  1   0   0    BURGLARY-SECURE PARKING-RES
#
#        Occurred Date or Date Range Start District/Sector Zone/Beat  \
# 0                 03/07/2013 04:29:00 PM               B        B2
# 1                 03/07/2014 10:00:00 PM               K        K1
# 2                 04/08/2014 10:30:00 AM               L        L1
# 3                 03/05/2013 03:30:00 PM               Q        Q3
# 4                 04/22/2014 06:15:00 PM               B        B1
# 5                 04/24/2014 05:30:00 AM               J        J2
# 6                 04/19/2014 11:30:00 PM               D        D3
# 7                 04/21/2014 10:30:00 PM               N        N3
# 8                 03/08/2013 05:00:00 PM               M        M2
# 9                 03/04/2013 08:00:00 PM               C        C3
# 10                03/06/2013 06:02:00 PM               Q        Q2
# 11                03/03/2013 09:30:00 AM               Q        Q3
# 12                03/07/2013 01:26:00 PM               Q        Q3
# 13                03/07/2013 11:00:00 AM               G        G3
# 14                08/21/2014 06:42:00 PM               L        L2
# 15                03/03/2013 10:00:00 PM               E        E1
# 16                03/07/2013 09:15:00 AM               N        N3
# 17                03/08/2013 11:07:00 AM               S        S3
# 18                03/08/2013 11:28:00 PM               O        O3
# 19                07/19/2014 02:00:00 PM               K        K1
# 20                03/08/2013 08:35:00 PM               F        F2
# 21                03/06/2013 06:00:00 PM               B        B1
# 22                03/07/2013 12:00:00 AM               W        W1
# 23                03/08/2013 08:39:00 PM               0         0
# 24                03/07/2013 12:13:00 AM               C        C1
# 25                03/07/2013 12:30:00 AM               W        W1
# 26                03/06/2013 08:30:00 PM               Q        Q2
# 27                08/19/2014 07:20:00 AM               R        R1
# 28                02/28/2013 10:00:00 PM               D        D3
# 29                05/25/2015 01:30:00 AM               M        M1
# ...                                  ...             ...       ...
# 498264            03/07/2013 07:00:00 PM               S        S2
# 498265            02/14/2013 10:00:00 AM               K        K1
# 498266            09/01/2012 12:00:00 AM               S        S3
# 498267            02/07/2013 08:00:00 AM               Q        Q2
# 498268            03/08/2013 01:58:00 PM               C        C3
# 498269            03/08/2013 02:18:00 PM               W        W1
# 498270            03/08/2013 06:27:00 PM               W        W1
# 498271            03/07/2013 07:30:00 AM               S        S3
# 498272            03/06/2013 08:00:00 AM               W        W2
# 498273            03/08/2013 12:13:00 AM               D        D1
# 498274            03/08/2013 01:55:00 AM               M        M3
# 498275            03/08/2013 02:40:00 AM               N        N1
# 498276            03/08/2013 02:48:00 AM               D        D1
# 498277            03/07/2013 11:26:00 PM               Q        Q3
# 498278            03/07/2013 10:10:00 AM               E        E1
# 498279            03/08/2013 01:55:00 PM               J        J3
# 498280            03/08/2013 12:00:00 AM               D        D3
# 498281            03/08/2013 06:07:00 PM               O        O1
# 498282            03/08/2013 05:30:00 PM               E        E1
# 498283            03/08/2013 02:56:00 PM               E        E2
# 498284            03/07/2013 02:20:00 PM               J        J2
# 498285            03/06/2013 07:30:00 PM               B        B3
# 498286            03/07/2013 11:00:00 PM               D        D3
# 498287            03/08/2013 08:03:00 AM               D        D2
# 498288            03/08/2013 10:28:00 PM               D        D1
# 498289            03/08/2013 11:00:00 AM               U        U1
# 498290            03/07/2013 04:54:00 PM               U        U2
# 498291            03/07/2013 07:00:00 PM               D        D2
# 498292            03/08/2013 04:55:00 PM               F        F1
# 498293            02/15/2013 12:01:00 AM               B        B2
#
#         Census Tract 2000  Month  Year Severity  Hour  Day  Night
# 0               3500.2037      3  2013      MED    16    1      0
# 1               8100.2036      3  2014     HIGH    22    0      1
# 2                200.2001      4  2014     HIGH    10    1      0
# 3               7200.1075      3  2013      MED    15    1      0
# 4               3300.4006      4  2014     HIGH    18    1      0
# 5               3000.4011      4  2014     HIGH     5    0      1
# 6               7300.2005      4  2014     HIGH    23    0      1
# 7               1200.5011      4  2014     HIGH    22    0      1
# 8               7200.1065      3  2013     HIGH    17    1      0
# 9               6300.4020      3  2013     HIGH    20    0      1
# 10              6800.2008      3  2013     HIGH    18    1      0
# 11              7200.1075      3  2013     HIGH     9    1      0
# 12              7000.6010      3  2013     HIGH    13    1      0
# 13              8900.3022      3  2013      MED    11    1      0
# 14              1200.3000      8  2014      MED    18    1      0
# 15              7402.1010      3  2013      MED    22    0      1
# 16              1300.1011      3  2013     HIGH     9    1      0
# 17             11900.1011      3  2013     HIGH    11    1      0
# 18             10900.2082      3  2013      MED    23    0      1
# 19              8100.1023      8  2014      MED    14    1      0
# 20             11402.1011      3  2013     HIGH    20    0      1
# 21              4700.4014      3  2013     HIGH    18    1      0
# 22              9600.3009      3  2013     HIGH     0    0      1
# 23                 0.0000      3  2013      MED    20    0      1
# 24              7500.2008      3  2013      MED     0    0      1
# 25              9701.2004      3  2013      MED     0    0      1
# 26              7000.1002      3  2013      MED    20    0      1
# 27              9300.1025      8  2014     HIGH     7    1      0
# 28              7300.3009      3  2013      MED    22    0      1
# 29              8100.3014      5  2015     HIGH     1    0      1
# ...                   ...    ...   ...      ...   ...  ...    ...
# 498264         11800.6003      3  2013      MED    19    1      0
# 498265          8100.2023      3  2013      MED    10    1      0
# 498266         11700.4005      3  2013      MED     0    0      1
# 498267          5900.1022      3  2013      MED     8    1      0
# 498268          8800.1012      3  2013      MED    13    1      0
# 498269          9900.1021      3  2013      MED    14    1      0
# 498270          9600.1006      3  2013      MED    18    1      0
# 498271         11800.2000      3  2013     HIGH     7    1      0
# 498272          9702.2000      3  2013     HIGH     8    1      0
# 498273          8001.2009      3  2013      MED     0    0      1
# 498274          8100.2007      3  2013      MED     1    0      1
# 498275          1400.3010      3  2013      MED     2    0      1
# 498276          8001.1005      3  2013      MED     2    0      1
# 498277          7100.1001      3  2013     HIGH    23    0      1
# 498278          8400.1003      3  2013      MED    10    1      0
# 498279          2700.4010      3  2013     HIGH    13    1      0
# 498280          6100.3010      3  2013      MED     0    0      1
# 498281          9300.1046      3  2013     HIGH    18    1      0
# 498282          7402.1000      3  2013      LOW    17    1      0
# 498283          8600.2006      3  2013      MED    14    1      0
# 498284          3000.1002      3  2013      MED    14    1      0
# 498285          5400.3002      3  2013      MED    19    1      0
# 498286          6600.1041      3  2013      MED    23    0      1
# 498287          7200.3000      3  2013      MED     8    1      0
# 498288          8001.2001      3  2013      LOW    22    0      1
# 498289          4400.4000      3  2013     HIGH    11    1      0
# 498290          5301.2001      3  2013     HIGH    16    1      0
# 498291          6700.1015      3  2013     HIGH    19    1      0
# 498292         10800.3011      3  2013     HIGH    16    1      0
# 498293          4900.4004      3  2013      MED     0    0      1
#
# [498294 rows x 18 columns]

# %%
df5 = df4.drop(['Summarized Offense Description','Occurred Date or Date Range Start','District/Sector','Hour'], axis=1)

# %%
df5.head()
# Out:
#    M  T  W  Th  F  Sa  Su Zone/Beat  Census Tract 2000  Month  Year Severity  \
# 0  0  0  0   1  0   0   0        B2          3500.2037      3  2013      MED
# 1  0  0  0   0  1   0   0        K1          8100.2036      3  2014     HIGH
# 2  0  1  0   0  0   0   0        L1           200.2001      4  2014     HIGH
# 3  0  1  0   0  0   0   0        Q3          7200.1075      3  2013      MED
# 4  0  1  0   0  0   0   0        B1          3300.4006      4  2014     HIGH
#
#    Day  Night
# 0    1      0
# 1    0      1
# 2    1      0
# 3    1      0
# 4    1      0

# %%
from sklearn import preprocessing 
le = preprocessing.LabelEncoder()
le.fit(['HIGH','MED','LOW'])
# Out:
# LabelEncoder()

# %%
le_severity = pd.DataFrame(le.transform(df5['Severity']))
le_severity.head()
# Out:
#    0
# 0  2
# 1  0
# 2  0
# 3  2
# 4  0

# %%
df5['Zone/Beat'].unique()
# Out:
# array(['B2', 'K1', 'L1', 'Q3', 'B1', 'J2', 'D3', 'N3', 'M2', 'C3', 'Q2',
#        'G3', 'L2', 'E1', 'S3', 'O3', 'F2', 'W1', 0, 'C1', 'R1', 'M1', 'R3',
#        'D1', 'L3', 'W3', 'S2', 'K3', 'E2', 'J1', 'M3', 'N1', 'W2', 'E3',
#        'U1', 'K2', 'G1', 'J3', 'Q1', 'S1', 'G2', 'B3', 'N2', 'R2', 'D2',
#        'F3', 'F1', 'C2', 'U2', 'U3', 'O2', 'O1', '99', 'WS'], dtype=object)

# %%
lec = preprocessing.LabelEncoder()
df5['Zone/Beat'] = lec.fit_transform(df5['Zone/Beat'].astype(str))

# %%
df5['Zone/Beat'].unique()
# Out:
# array([ 3, 23, 26, 40,  2, 21, 10, 34, 30,  7, 39, 19, 27, 11, 46, 37, 15,
#        50,  0,  5, 41, 29, 43,  8, 28, 52, 45, 25, 12, 20, 31, 32, 51, 13,
#        47, 24, 17, 22, 38, 44, 18,  4, 33, 42,  9, 16, 14,  6, 48, 49, 36,
#        35,  1, 53])

# %%
df5['Severity'] = le_severity ## 2 is MED, 1 is low,0 is high

# %%
let = preprocessing.LabelEncoder()
df5['Year'] = let.fit_transform(df5['Year'])
df5.head()
# Out:
#    M  T  W  Th  F  Sa  Su  Zone/Beat  Census Tract 2000  Month  Year  \
# 0  0  0  0   1  0   0   0          3          3500.2037      3     0
# 1  0  0  0   0  1   0   0         23          8100.2036      3     1
# 2  0  1  0   0  0   0   0         26           200.2001      4     1
# 3  0  1  0   0  0   0   0         40          7200.1075      3     0
# 4  0  1  0   0  0   0   0          2          3300.4006      4     1
#
#    Severity  Day  Night
# 0         2    1      0
# 1         0    0      1
# 2         0    1      0
# 3         2    1      0
# 4         0    1      0

# %%
from sklearn.model_selection import train_test_split
feat_cols = ['M','T','W','Th','F','Sa','Su','Census Tract 2000', 'Month', 'Year','Severity','Day','Night']
X = df5[feat_cols]
y = df5['Zone/Beat']

# %%
from sklearn import decomposition

pca = decomposition.PCA()
pca.fit(X)
X = pca.transform(X)
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_jobs=100, random_state=0)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=100,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
y_pred_class = clf.predict(X_test)

# %%
from sklearn import metrics

print("Accuracy score: {0:.4f}".format(metrics.accuracy_score(y_test, y_pred_class)))
# Out:
# Accuracy score: 0.8755

# %%
Yloc_test = list(lec.inverse_transform(y_test))

# %%
Yloc_pred_class = list(lec.inverse_transform(y_pred_class))

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_class)) # , target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.70      0.55      0.62       167
#           1       0.70      0.65      0.67       205
#           2       0.86      0.91      0.88      2723
#           3       0.91      0.88      0.90      2909
#           4       0.96      0.95      0.96      2973
#           5       0.80      0.80      0.80      2077
#           6       0.80      0.79      0.79      1648
#           7       0.81      0.79      0.80      1705
#           8       0.88      0.90      0.89      2889
#           9       0.79      0.81      0.80      2781
#          10       0.85      0.84      0.85      2469
#          11       0.91      0.92      0.91      3185
#          12       0.88      0.91      0.89      4133
#          13       0.87      0.89      0.88      2598
#          14       0.86      0.88      0.87      1889
#          15       0.95      0.97      0.96      2283
#          16       0.97      0.99      0.98      2079
#          17       0.83      0.82      0.82      1825
#          18       0.80      0.81      0.80      1799
#          19       0.85      0.84      0.85      2132
#          20       0.92      0.94      0.93      2082
#          21       0.86      0.87      0.86      2124
#          22       0.89      0.90      0.90      2445
#          23       0.84      0.82      0.83      2630
#          24       0.78      0.81      0.80      2556
#          25       0.84      0.84      0.84      2657
#          26       0.82      0.85      0.84      2178
#          27       0.95      0.94      0.94      3002
#          28       0.85      0.81      0.83      1922
#          29       0.87      0.84      0.85      3025
#          30       0.83      0.84      0.84      3813
#          31       0.85      0.85      0.85      3557
#          32       0.85      0.83      0.84      1900
#          33       0.89      0.90      0.89      2946
#          34       0.95      0.95      0.95      3342
#          35       0.84      0.86      0.85      1518
#          36       0.78      0.76      0.77      1087
#          37       0.87      0.87      0.87      1267
#          38       0.96      0.97      0.96      1907
#          39       0.89      0.87      0.88      2792
#          40       0.91      0.91      0.91      3196
#          41       0.79      0.80      0.79      1991
#          42       0.86      0.86      0.86      2496
#          43       0.92      0.92      0.92      2233
#          44       0.91      0.85      0.88      1681
#          45       0.82      0.82      0.82      1823
#          46       0.85      0.87      0.86      2106
#          47       0.92      0.91      0.91      3418
#          48       0.95      0.97      0.96      3204
#          49       0.97      0.95      0.96      3111
#          50       0.84      0.87      0.85      1904
#          51       0.85      0.82      0.84      2334
#          52       0.89      0.84      0.86      1858
#
# avg / total       0.88      0.88      0.88    124574

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, y_pred_class)
# Out:
# array([[  92,   44,    0, ...,    0,    0,    0],
#        [  33,  133,    0, ...,    0,    1,    0],
#        [   0,    0, 2479, ...,    0,    0,    0],
#        ...,
#        [   0,    2,    0, ..., 1650,  130,    0],
#        [   0,    0,    0, ...,  220, 1918,   69],
#        [   0,    0,    0, ...,    0,   80, 1555]])

# %% [markdown]
# While the two cells above can provide some useful insights via sklearn.metrics , I would prefer to see more explicitly defined evaluations of my model:

# %%
index = []
results = []  ## What the true target district was that our model misclassified 
misses = []   ## What the model predicted our target district was when it was incorrect. 
for i in range(len(Yloc_test)):
    
    if Yloc_pred_class[i] != Yloc_test[i]:          
        index.append(i)
        results.append(Yloc_test[i])
        misses.append(Yloc_pred_class[i])

# %%
misses
# Out:
# ['L1',
#  'M2',
#  'W3',
#  'S2',
#  'N2',
#  'U1',
#  'M2',
#  'M3',
#  'F1',
#  'J2',
#  'W2',
#  'J2',
#  'M2',
#  'S2',
#  'L2',
#  'F1',
#  'S3',
#  'J3',
#  'J2',
#  'J1',
#  'R2',
#  'S2',
#  'M3',
#  'R1',
#  'M3',
#  'J2',
#  'N1',
#  'K2',
#  'Q2',
#  'W2',
#  'R2',
#  'F3',
#  'G1',
#  'D2',
#  'S2',
#  'R1',
#  'D1',
#  'Q2',
#  'Q3',
#  'D2',
#  'D2',
#  'M1',
#  'L1',
#  'E2',
#  'K1',
#  'D3',
#  'R2',
#  'L1',
#  'L1',
#  'G1',
#  'U2',
#  'G1',
#  'N2',
#  'C1',
#  'L3',
#  'C2',
#  'D2',
#  'L2',
#  'K2',
#  'J2',
#  'O3',
#  'N2',
#  'C2',
#  'D2',
#  'G3',
#  'N1',
#  'J2',
#  'Q1',
#  'L1',
#  'D3',
#  'O1',
#  'U2',
#  'B2',
#  'Q3',
#  'D3',
#  'O2',
#  'Q3',
#  'K1',
#  'M2',
#  '0',
#  'C1',
#  'L1',
#  'U1',
#  'N1',
#  'B3',
#  'K2',
#  'J3',
#  'E2',
#  'N3',
#  'C2',
#  'S1',
#  'E1',
#  'B1',
#  'F1',
#  'O2',
#  'E1',
#  'E1',
#  'F1',
#  'L3',
#  'M2',
#  'D2',
#  'U1',
#  'Q1',
#  'R2',
#  'L3',
#  'C2',
#  'D2',
#  'D3',
#  'N2',
#  'S3',
#  'C1',
#  'K3',
#  'M3',
#  'G1',
#  'E3',
#  'G2',
#  'E2',
#  'G1',
#  'M2',
#  'R1',
#  'O3',
#  'N2',
#  'M3',
#  'F1',
#  'K1',
#  'W2',
#  'L1',
#  'L1',
#  'R1',
#  'J2',
#  'M2',
#  'K1',
#  'F1',
#  'D3',
#  'N2',
#  'S1',
#  'E1',
#  'J3',
#  'G3',
#  'K3',
#  'M3',
#  'D2',
#  'C1',
#  'C2',
#  'R2',
#  'M2',
#  'E3',
#  'G1',
#  'D2',
#  'J1',
#  'E2',
#  'R1',
#  'K1',
#  'R1',
#  'C3',
#  'U2',
#  'C2',
#  'C3',
#  'F1',
#  'N3',
#  'D1',
#  'W3',
#  'L1',
#  'E3',
#  'C1',
#  'O1',
#  'G2',
#  'J2',
#  'M2',
#  'S1',
#  'R2',
#  'M3',
#  'L3',
#  'C2',
#  'G2',
#  'M1',
#  'O2',
#  'M1',
#  'W1',
#  'B2',
#  'D2',
#  'K1',
#  'R1',
#  'U1',
#  'J2',
#  'U1',
#  'M2',
#  'G2',
#  'E1',
#  'S2',
#  'O1',
#  'F1',
#  'M2',
#  'R1',
#  'D3',
#  'E2',
#  'U1',
#  'M2',
#  'U3',
#  'C2',
#  'N1',
#  'N2',
#  'R2',
#  'M1',
#  'G1',
#  'K1',
#  'W3',
#  'D2',
#  'M1',
#  'S2',
#  'R3',
#  'N1',
#  'G2',
#  'K1',
#  'D1',
#  'R2',
#  'E3',
#  'E3',
#  'M1',
#  'M3',
#  'L1',
#  'C2',
#  'K3',
#  'O3',
#  'M2',
#  'M2',
#  'C1',
#  'M1',
#  'M1',
#  'E3',
#  'R3',
#  'K2',
#  'F2',
#  'D1',
#  'G1',
#  'M3',
#  'M2',
#  'Q2',
#  'L2',
#  'B2',
#  'Q2',
#  'J3',
#  'G3',
#  'O1',
#  'M2',
#  'O3',
#  'B1',
#  'E2',
#  'L3',
#  'C1',
#  'R3',
#  'O2',
#  'K1',
#  'G2',
#  'D3',
#  'Q3',
#  'J2',
#  'N3',
#  'L1',
#  'O3',
#  'G2',
#  'O1',
#  'M3',
#  'M2',
#  'Q2',
#  'F1',
#  'C1',
#  'B1',
#  'G3',
#  'Q2',
#  'E1',
#  'E1',
#  'D2',
#  'L3',
#  'C2',
#  'G2',
#  'W2',
#  'M2',
#  'M1',
#  'R1',
#  'C3',
#  'E1',
#  'K3',
#  'M2',
#  'M1',
#  'K2',
#  'N3',
#  'L3',
#  'L1',
#  'W1',
#  'S2',
#  'N3',
#  'C3',
#  'J3',
#  'R1',
#  'W1',
#  'E1',
#  'S2',
#  'R2',
#  'L3',
#  'B1',
#  'W2',
#  'S2',
#  'D2',
#  'L2',
#  'O1',
#  'M3',
#  'D3',
#  'M3',
#  'C1',
#  'M2',
#  'B1',
#  'L2',
#  'W3',
#  'K3',
#  'K1',
#  'M3',
#  'B1',
#  'J2',
#  'B1',
#  'W1',
#  'D3',
#  'M2',
#  'W2',
#  'L3',
#  'Q1',
#  'K2',
#  'R2',
#  'R2',
#  'U1',
#  'L3',
#  'U3',
#  'M3',
#  'K2',
#  'M2',
#  'R1',
#  'L1',
#  'K2',
#  'R1',
#  'D3',
#  'D3',
#  'M3',
#  'Q3',
#  'J1',
#  'D2',
#  'O1',
#  'L3',
#  'D3',
#  'D1',
#  'E2',
#  'N1',
#  'L1',
#  'C1',
#  'R3',
#  'L3',
#  'W2',
#  'D2',
#  'M2',
#  'S2',
#  'K2',
#  'K3',
#  'O2',
#  'N2',
#  'R1',
#  'E3',
#  'C2',
#  'B1',
#  'D2',
#  'U3',
#  'M3',
#  'N1',
#  'M2',
#  'M1',
#  'K3',
#  'U2',
#  'Q2',
#  'W2',
#  'N2',
#  'F1',
#  'B1',
#  'L1',
#  'R3',
#  'M1',
#  'K1',
#  'U2',
#  'R1',
#  'S3',
#  'S3',
#  'U3',
#  'W2',
#  'M2',
#  'L2',
#  'J3',
#  'K2',
#  'U1',
#  'D1',
#  'E2',
#  'J3',
#  'K3',
#  'B1',
#  'R2',
#  'J2',
#  'S3',
#  'R1',
#  'C2',
#  'E2',
#  'D2',
#  'M3',
#  'D3',
#  'F1',
#  'M1',
#  'E2',
#  'E1',
#  'F1',
#  'K1',
#  'J2',
#  'M2',
#  'S2',
#  'K1',
#  'M3',
#  'D2',
#  'S2',
#  'C3',
#  'M3',
#  'B2',
#  'C1',
#  '99',
#  'S3',
#  'K3',
#  'U3',
#  'W1',
#  'K2',
#  'E3',
#  'J3',
#  'U1',
#  'E2',
#  'B2',
#  'S3',
#  'D1',
#  'W1',
#  'F2',
#  'D1',
#  'E2',
#  'C1',
#  'S2',
#  'B3',
#  'M3',
#  'M3',
#  'J3',
#  'B1',
#  'O3',
#  'Q2',
#  'D1',
#  'W3',
#  'J2',
#  'S2',
#  'D2',
#  'M3',
#  'M1',
#  'M1',
#  'S2',
#  'W1',
#  'M1',
#  'Q2',
#  'M3',
#  'G1',
#  'J1',
#  'G1',
#  'M1',
#  'Q2',
#  'W1',
#  'G1',
#  'D1',
#  'N2',
#  'M1',
#  'G2',
#  'M2',
#  'Q2',
#  'G1',
#  'R1',
#  'D2',
#  'R1',
#  'O1',
#  'O2',
#  'O1',
#  'E3',
#  'O2',
#  'M1',
#  'S3',
#  'N1',
#  'R2',
#  'C2',
#  'C1',
#  'Q2',
#  'Q2',
#  'W1',
#  'B1',
#  'B2',
#  'B2',
#  'M1',
#  'W3',
#  'E1',
#  'W2',
#  'J2',
#  'M1',
#  'Q3',
#  'S3',
#  'S3',
#  'W2',
#  'M2',
#  'C1',
#  'D1',
#  'W3',
#  'K2',
#  'O2',
#  'S3',
#  'Q2',
#  'B1',
#  'S3',
#  'U2',
#  'S2',
#  'L2',
#  'K2',
#  'M1',
#  'R1',
#  'D1',
#  'N1',
#  'G3',
#  'G1',
#  'W1',
#  'L1',
#  'N2',
#  'S3',
#  'E2',
#  'B2',
#  'C1',
#  'U1',
#  'Q2',
#  'K2',
#  'D2',
#  'N2',
#  'K3',
#  'L1',
#  'K1',
#  'S3',
#  'Q2',
#  'E2',
#  'F1',
#  'O3',
#  'D1',
#  'L1',
#  'Q2',
#  'F1',
#  'C1',
#  'L1',
#  'D2',
#  'M2',
#  'K1',
#  'C1',
#  'Q2',
#  'K3',
#  'C3',
#  'E1',
#  'O2',
#  'G1',
#  'N3',
#  'G2',
#  'K3',
#  'K1',
#  'G3',
#  'D3',
#  'K1',
#  'R3',
#  'R2',
#  'M3',
#  'B2',
#  'D2',
#  'M2',
#  'U3',
#  'J2',
#  'U1',
#  'O1',
#  'U2',
#  'E3',
#  'D2',
#  'D2',
#  'D3',
#  'E3',
#  'K3',
#  'L3',
#  'S3',
#  'R3',
#  'B1',
#  'U1',
#  'M2',
#  'O2',
#  'G1',
#  'W2',
#  'E3',
#  'C1',
#  'N1',
#  'D2',
#  'S2',
#  'R2',
#  'L3',
#  'F1',
#  'C1',
#  'J1',
#  'K3',
#  'B3',
#  'K1',
#  'B1',
#  'R2',
#  'L2',
#  'G3',
#  'E1',
#  'B1',
#  'B1',
#  'M2',
#  'G3',
#  'U2',
#  'D3',
#  '0',
#  'K2',
#  'C1',
#  'W1',
#  'N3',
#  'L2',
#  'W1',
#  'R2',
#  'Q2',
#  'C1',
#  'D2',
#  'L1',
#  'L1',
#  'U3',
#  'O2',
#  'U1',
#  'M1',
#  'O3',
#  'S2',
#  'M2',
#  'M2',
#  'C2',
#  'G2',
#  'W2',
#  'C1',
#  'B1',
#  'M2',
#  'M1',
#  'S1',
#  'M1',
#  'B3',
#  'G1',
#  'N1',
#  'D1',
#  'C2',
#  '0',
#  'W2',
#  'N3',
#  'D2',
#  'O1',
#  'O3',
#  'K2',
#  'U2',
#  'G2',
#  'D3',
#  'K1',
#  'K3',
#  'M1',
#  'C1',
#  'R2',
#  'B1',
#  'K1',
#  'B3',
#  'K1',
#  'C2',
#  'C2',
#  'M3',
#  'D3',
#  'C1',
#  'F2',
#  'D2',
#  'G1',
#  'F2',
#  'W2',
#  'K3',
#  'E1',
#  'M3',
#  'B1',
#  'M2',
#  'G3',
#  'E3',
#  'S1',
#  'S2',
#  'J2',
#  'K1',
#  'F2',
#  'R2',
#  'K3',
#  'W3',
#  'L3',
#  'J3',
#  'W2',
#  'W3',
#  'L3',
#  'U2',
#  'U1',
#  'D1',
#  'E3',
#  'L2',
#  'M3',
#  'F2',
#  'G3',
#  'J1',
#  'M2',
#  'D1',
#  'M1',
#  'D1',
#  'D2',
#  'C3',
#  'E1',
#  'S3',
#  'S3',
#  'K2',
#  'L3',
#  'O1',
#  'O3',
#  'U1',
#  'K1',
#  'W2',
#  'M2',
#  'Q2',
#  'K2',
#  'M2',
#  'M2',
#  'R1',
#  'U2',
#  'E2',
#  'D2',
#  'K3',
#  'N3',
#  'R3',
#  'O2',
#  'L2',
#  'B2',
#  'N1',
#  'J3',
#  'L3',
#  'B2',
#  'M3',
#  'M3',
#  'U1',
#  'L1',
#  'R3',
#  'S3',
#  'L3',
#  'G2',
#  'R1',
#  'G2',
#  'G1',
#  'B2',
#  'M3',
#  'G1',
#  'J1',
#  'R2',
#  'R1',
#  'M3',
#  'C3',
#  'B1',
#  'E2',
#  'O1',
#  'W2',
#  'L1',
#  'G1',
#  'F1',
#  'K2',
#  'O2',
#  'U1',
#  'K3',
#  'W2',
#  'S1',
#  'M2',
#  '0',
#  'M2',
#  'K2',
#  'R1',
#  'K3',
#  'D2',
#  'F1',
#  'C2',
#  'M3',
#  'G3',
#  'E2',
#  'M3',
#  'B1',
#  'R1',
#  'F1',
#  'B1',
#  'B1',
#  'K3',
#  'C2',
#  'R2',
#  'K2',
#  'B1',
#  'J2',
#  'M3',
#  'C2',
#  'C1',
#  'L1',
#  'J3',
#  'Q2',
#  'L1',
#  '99',
#  'C2',
#  'G3',
#  'D3',
#  'R1',
#  'O3',
#  'J1',
#  'M2',
#  'R1',
#  'M1',
#  'C2',
#  'Q3',
#  'R1',
#  'K3',
#  'U2',
#  'M3',
#  'Q2',
#  'M2',
#  'K1',
#  'E1',
#  'R1',
#  'S3',
#  'S2',
#  'C1',
#  'Q3',
#  'J2',
#  'Q3',
#  'W1',
#  'J3',
#  'M2',
#  'Q3',
#  'G2',
#  'M3',
#  'J3',
#  'K2',
#  'K3',
#  'G3',
#  'Q3',
#  'K2',
#  'S2',
#  'J3',
#  'G1',
#  'F3',
#  'M2',
#  'S2',
#  'K3',
#  'O3',
#  'W2',
#  'D2',
#  'D3',
#  'K2',
#  'O1',
#  'D2',
#  'N2',
#  'L1',
#  'S2',
#  'B1',
#  'B1',
#  'S3',
#  'C3',
#  'J2',
#  'M3',
#  'G3',
#  'G2',
#  'G2',
#  'C3',
#  'C1',
#  'C2',
#  'M1',
#  'M2',
#  'Q3',
#  'J2',
#  'F2',
#  'M2',
#  'D2',
#  'F1',
#  'C1',
#  'D2',
#  'M2',
#  'M2',
#  'U1',
#  'J1',
#  'G3',
#  'J2',
#  'K2',
#  'G2',
#  'N2',
#  'G3',
#  'O3',
#  'C2',
#  'S2',
#  'C2',
#  'E2',
#  'N1',
#  'L1',
#  'D2',
#  'Q2',
#  'C1',
#  'M2',
#  'M1',
#  'W2',
#  'N2',
#  'D2',
#  'M3',
#  'S3',
#  'L1',
#  'M3',
#  'N2',
#  'R2',
#  'L3',
#  'N2',
#  'B1',
#  'E1',
#  'M1',
#  'G2',
#  'O1',
#  'C3',
#  'W2',
#  'K2',
#  'D2',
#  'G3',
#  'O2',
#  'G3',
#  'N3',
#  'D3',
#  'M2',
#  'R3',
#  'E1',
#  'U1',
#  '0',
#  'N2',
#  'W1',
#  'G1',
#  'M2',
#  'B1',
#  'N3',
#  'J1',
#  'K3',
#  'K3',
#  'C2',
#  'M3',
#  'G2',
#  'F1',
#  'J3',
#  'G3',
#  'E1',
#  'K3',
#  'D2',
#  'W3',
#  'M2',
#  'E3',
#  'M2',
#  'L3',
#  'W2',
#  'C2',
#  'G2',
#  'L3',
#  'K1',
#  'L2',
#  'K3',
#  'C2',
#  'E1',
#  'E3',
#  'B1',
#  'J3',
#  'B1',
#  'E2',
#  'W1',
#  'B1',
#  'M1',
#  'O1',
#  'M2',
#  'D2',
#  'G2',
#  'O1',
#  'B1',
#  'K3',
#  'S1',
#  'Q3',
#  'F1',
#  'C2',
#  'M1',
#  'K2',
#  'S3',
#  'C2',
#  'M3',
#  'N1',
#  ...]

# %%
a = pd.DataFrame(list(zip(misses,results)))
a
# Out:
#         0   1
# 0      L1  L3
# 1      M2  Q3
# 2      W3  W2
# 3      S2  S3
# 4      N2  N3
# 5      U1  L2
# 6      M2  D2
# 7      M3  M2
# 8      F1  W2
# 9      J2  B1
# 10     W2  W3
# 11     J2  J3
# 12     M2  M3
# 13     S2  R3
# 14     L2  N3
# 15     F1  O3
# 16     S3  S2
# 17     J3  L2
# 18     J2  B1
# 19     J1  B1
# 20     R2  W1
# 21     S2  S3
# 22     M3  K1
# 23     R1  G3
# 24     M3  M2
# 25     J2  B1
# 26     N1  N2
# 27     K2  K3
# 28     Q2  D2
# 29     W2  W3
# ...    ..  ..
# 15476  D1  M1
# 15477  E1  E3
# 15478  C1  C3
# 15479  B3  U2
# 15480  R1  R2
# 15481  R3  R2
# 15482  D3  C2
# 15483  J2  B1
# 15484  R1  R3
# 15485  J2  B2
# 15486  M2  E3
# 15487  J1  J2
# 15488  D1  M1
# 15489  C1  C2
# 15490  F1  W2
# 15491  E3  M2
# 15492  M3  M2
# 15493  C3  G2
# 15494  N1  N2
# 15495  K2  K3
# 15496  S2  S1
# 15497  Q1  Q2
# 15498  K2  G3
# 15499  M3  M2
# 15500  Q2  D2
# 15501  S1  W3
# 15502  D1  M1
# 15503  D2  D3
# 15504  R1  R2
# 15505  B2  B1
#
# [15506 rows x 2 columns]

# %%
Misses = pd.Series(misses)
Misses.value_counts()
# Out:
# M2    651
# D2    589
# K2    570
# M3    553
# E2    500
# R1    426
# K3    410
# C1    403
# B1    401
# K1    395
# L1    392
# M1    374
# G2    358
# D3    352
# R2    347
# D1    343
# W2    338
# N2    336
# S2    335
# E3    332
# C2    327
# S3    324
# C3    322
# G3    312
# G1    306
# W1    306
# Q2    301
# E1    300
# J2    300
# L3    287
# Q3    287
# U1    276
# N1    275
# J3    264
# F1    264
# O1    249
# B2    242
# O2    234
# W3    191
# R3    190
# N3    179
# O3    169
# J1    168
# L2    152
# U2    150
# S1    137
# F2    125
# B3    121
# U3     94
# Q1     84
# F3     67
# 99     58
# 0      40
# dtype: int64

# %%
Results = pd.Series(results)
Results.value_counts()
# Out:
# M2    604
# M3    529
# D2    522
# M1    495
# K2    491
# K1    480
# K3    438
# W2    416
# C1    416
# D3    405
# R1    402
# E2    391
# Q2    361
# C3    359
# L3    357
# C2    348
# G2    348
# R2    341
# B2    339
# G3    337
# G1    332
# L1    330
# S2    327
# N1    323
# U1    314
# N2    303
# W3    303
# D1    299
# E3    296
# Q3    279
# J2    278
# S3    271
# E1    268
# O2    264
# W1    254
# S1    251
# B1    244
# J3    236
# F1    236
# O1    209
# L2    194
# R3    185
# O3    162
# N3    156
# U3    148
# J1    135
# B3    134
# U2     98
# 0      75
# 99     72
# F2     63
# Q1     57
# F3     31
# dtype: int64

# %% [markdown]
# From the above, it appears as though the M2 and M3 classes are two excessive troublemakers in our dataset. Lets explore what classes are incorrectly misclassified as M2 and M3 the most often:

# %%
listo = ['M2','M3']
things = [[],[]]
for line in range(len(Misses)):
    for i in range(len([listo])):
        if listo[i] == Results[line]:
            things[i].append(Misses[line])
            #print(Misses[line])
        elif listo[i+1] == Results[line]:
            things[i+1].append(Misses[line])

# %%
Things0 = pd.Series(things[0])
Things1 = pd.Series(things[1])

M2 = Things0.value_counts()
M2
# Out:
# M3    248
# D2    111
# M1     51
# Q3     43
# D1     29
# D3     28
# E3     28
# K1     22
# E1     21
# K2     17
# E2      3
# K3      3
# dtype: int64

# %%
M3 = Things1.value_counts()
M3
# Out:
# M2    296
# K1    106
# M1     93
# K2     20
# E3      8
# K3      4
# D1      2
# dtype: int64

# %%
plt.plot(M2, 'ro')
plt.show()

# %%
plt.plot(M3, 'ro')
plt.show()

# %% [markdown]
# K1, K2, E3, and M1 are zones/beats that are commonly misclassified as both M2 and M3 by the RandomForest.
#
# The following map gives one a good idea of how the misclassified Zones/Beats relate geograpically to the neighborhoods that they are most commonly confused by:
#
# https://www.seattle.gov/police/information-and-data/tweets-by-beat
#
# It is my hypothesis that the census tract number in our dataset is the feature that makes geographically similar locations so likely to be misclassified as each other.

# %% [markdown]
# Next Steps:
# I think that a very intriguing path forward for this dataset would be to attempt to classify whether or not a crime occurred at "night", using different definitions of night-time (possibly even working in the time of year as a means of tuning this feature).
#
# I also think that different types of engineered features (like a StandardScaler on the Census Tract 2000 number and omission of PCA) might be worth investigating in the future.
#
# I feel as though I know my way around this dataset pretty well by now, so I expect to develop more models using this data in the near future.
